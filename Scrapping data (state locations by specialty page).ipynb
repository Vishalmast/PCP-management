# %%
import requests 
from bs4 import BeautifulSoup 
import csv

# %%
from selenium import webdriver

# %%
path = "C:\Program Files (x86)\chromedriver.exe"

# %%
driver = webdriver.Chrome(path)

# %%
driver.get("https://www.vitals.com//locations/colorectal-surgeons")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup
# Out:
# <html class="async-hide" lang="en"><head><script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script async="" src="https://rules.quantcount.com/rules-p-gYd62cNm0pRBt.js"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://secure.quantserve.com/quant.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-W55B"></script><script>window.gdprMatch = false</script>
# <meta charset="utf-8"/>
# <meta content="en-us" http-equiv="content-language"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/> <script src="/cdn-cgi/apps/head/Iic6XbGi34RIOAyCpJeAAofGvNU.js"></script><script>
#             var s_not_pageview='y',
#                 s_account="webmdcom",
#                 s_site = "vitals",
#                 s_company = "webmd";
#
#             // Global Context Data
#             var s_context;
#             s_context = s_context || {};
#         </script>
# <script async="" src="//assets.adobedtm.com/launch-EN6438801bb371457fbcb9e3af700c3a0d.min.js"></script>
# <script>
#                             var dataLayer = dataLayer || [];
#             dataLayer.push({ "slim.routeName": "locations\/specialty "});
#             dataLayer.push({ "contentGroup2": "Shop"});
#
#                             dataLayer.push({"gaServerAddr":"192.168.6.15"});
#
#
#     dataLayer.push(
# {
#     "md": {
#         "uxv": "default"
#     },
#     "dd": {
#         "pt": "doctor",
#         "bm": "exact"
#     }
# }
# );
#
#     dataLayer.push({"dd": { "sp": "Colon and Rectal Surgery" }});
#
#
#         </script>
# <script>
#             var dataLayer = dataLayer || [];
#             dataLayer.push({"gaContentGroup":'Locations Specialty'});
#         </script>
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-W62MKH2':true});</script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W55B');</script>
# <meta content="Find great doctors at Vitals. Read ratings and reviews from other patients, get insurance information, hours and locations, and book an appointment online." name="description"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <meta content="noodp, noydir" name="robots"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@vitals" name="twitter:site"/>
# <meta content="@vitals" name="twitter:creator"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-48x48.png" rel="icon" sizes="48x48" type="image/png"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594470/logos/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//mdxvitals-res.cloudinary.com/image/upload/v1503594846/logos/favicon-192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link as="font" crossorigin="anonymous" href="/font/MDX-Icons.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/font/fa-regular-400.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/font/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/font/fa-brands-400.woff2" rel="preload" type="font/woff2"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="//mdxvitals-res.cloudinary.com/image/upload/v1503595046/logos/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <title>Find Colorectal Surgeons by City and State | Vitals.com</title>
# <link href="https://www.vitals.com/locations/colorectal-surgeons" rel="canonical"/>
# <meta content="document" name="resource-type"/>
# <meta content="Vitals" name="publisher"/>
# <meta content="EN" http-equiv="Content-Language"/>
# <meta content="Global" name="distribution"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Copyright 2020 Vitals" name="copyright"/>
# <meta content="info@vitals.com" http-equiv="Reply-to"/>
# <link href="/styles/browse.min.49331dc832.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#             <script type="text/javascript" src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#             <script type="text/javascript" src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#         <![endif]-->
# <script type="text/javascript">
#                 var adSlots = adSlots || [];
#                 var googletag = googletag || {};
#                 googletag.cmd = googletag.cmd || [];
#                 (function() {
#                     var gads = document.createElement('script');
#                     gads.async = true;
#                     gads.type = 'text/javascript';
#                     var useSSL = 'https:' == document.location.protocol;
#                     gads.src = (useSSL ? 'https:' : 'http:') +
#                         '//www.googletagservices.com/tag/js/gpt.js';
#                     var node = document.getElementsByTagName('script')[0];
#                     node.parentNode.insertBefore(gads, node);
#                 })();
#             </script>
# <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020082601.js?21067310"></script><link href="https://cdn.jsdelivr.net/npm/leaflet@1.3.4/dist/leaflet.min.css" rel="stylesheet" type="text/css"/><link href="https://cdn.jsdelivr.net/npm/leaflet-routing-machine@3.2.11/dist/leaflet-routing-machine.min.css" rel="stylesheet" type="text/css"/><link href="https://cdn.jsdelivr.net/npm/leaflet-control-geocoder@1.6.0/dist/Control.Geocoder.min.css" rel="stylesheet" type="text/css"/><style type="text/css">#consent_blackbar {position: fixed; bottom: 0; width: 100%; z-index: 100000000000000;}.truste-button2 {box-shadow: none;}.truste-button2:hover {background-color: inherit;}@media screen and (max-width: 790px){.truste-button2 {position: absolute !important;}}</style><script async="" src="https://assets.adobedtm.com/2c8c1e17b98c/fc5665aa5c2d/b2be9f6b1aa4/RC4c314b107d2541d5ad50897bd993e64f-source.min.js"></script><script async="" src="https://assets.adobedtm.com/2c8c1e17b98c/fc5665aa5c2d/b2be9f6b1aa4/RCbbad522977164a9f8f0c38d910e73da6-source.min.js"></script><script async="" crossorigin="anonymous" src="https://ibclick.stream/assets/js/track/dist/js/v1/tracker.min.js"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/734853681/?random=1598532094895&amp;cv=9&amp;fst=1598532094895&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=330&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg8j2&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.vitals.com%2F%2Flocations%2Fcolorectal-surgeons&amp;tiba=Find%20Colorectal%20Surgeons%20by%20City%20and%20State%20%7C%20Vitals.com&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/772998060/?random=1598532094900&amp;cv=9&amp;fst=1598532094900&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=330&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg8j2&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.vitals.com%2F%2Flocations%2Fcolorectal-surgeons&amp;tiba=Find%20Colorectal%20Surgeons%20by%20City%20and%20State%20%7C%20Vitals.com&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script></head>
# <body class="grey lighten-5">
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-W55B" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="valign-wrapper deep-purple" id="search-header">
# <i class="hide-on-tablet-and-up icons-search white-text show-form" data-header="vitals_logo"></i>
# <a data-header="vitals_logo" href="/">
# <img alt="Find a doctor - doctor reviews and ratings" class="logo lazyautosizes lazyloaded" data-header="vitals_logo" data-sizes="auto" data-src="//mdxvitals-res.cloudinary.com/image/upload/q_auto/f_auto/w_170,dpr_auto/v1539285855/vitals-logo-02.png" data-srcset="//mdxvitals-res.cloudinary.com/image/upload/q_auto/f_auto/w_170,dpr_auto/v1539285855/vitals-logo-02.png 1x,
#                         //mdxvitals-res.cloudinary.com/image/upload/q_auto/f_auto/w_170,dpr_2/v1539285855/vitals-logo-02.png 2x" sizes="154px" src="//mdxvitals-res.cloudinary.com/image/upload/q_auto/f_auto/w_170,dpr_auto/v1539285855/vitals-logo-02.png" srcset="//mdxvitals-res.cloudinary.com/image/upload/q_auto/f_auto/w_170,dpr_auto/v1539285855/vitals-logo-02.png 1x,
#                         //mdxvitals-res.cloudinary.com/image/upload/q_auto/f_auto/w_170,dpr_2/v1539285855/vitals-logo-02.png 2x"/>
# </a>
# <form class="search-box">
# <span class="hide-on-tablet-and-up white-text uppercase hide-form">cancel</span>
# <div class="search-container">
# <i class="fa fa-search grey-text text-darken-2"></i>
# <div class="input-field">
# <input class="form-control fc-alt" id="search-query" label="Search Keyword" placeholder="Name, Specialty, Facility" type="text"/>
# </div>
# </div>
# <div class="location-container">
# <i class="fa fa-location-arrow grey-text text-darken-2"></i>
# <div class="input-field">
# <input autocomplete="off" class="search-places-header" placeholder="City, State or Zip" type="text"/>
# </div>
# <div class="autocomplete-suggestions" style="position: absolute; display: none; max-height: 300px; z-index: 9999;"></div></div>
# <div class="btn btn-primary btn-search" id="search-button">
#             Find a Doctor
#         </div>
# </form>
# <button class="btn sidenav-trigger" data-target="slide-out" type="button">
# <i class="fa fa-bars"></i>
# <span class="hide-on-med-and-down">Browse</span>
# </button>
# </div>
# <script>
#     var searchPageURL = '/search',
#         searchHeader = document.getElementById("search-header");
#
#     if (window.innerWidth <=767 && (window.location.pathname === searchPageURL)) {
#         searchHeader.classList.add("show-form");
#     }
# </script>
# <header>
# <nav class="nav-extended">
# <div class="nav-content browse pin-top" style="top: 0px;">
# <div class="leaderboard grey lighten-3 center">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="leaderboard_top">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'leaderboard_top'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="leaderboard_top_no_billboard">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'leaderboard_top_no_billboard'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="pinned-padding"></div>
# </nav>
# </header>
# <main class="container">
# <!-- left rail -->
# <div class="hide-on-small-only left-rail advert-wrapper">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="skyscraper">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'skyscraper'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- browse content -->
# <div class="browse">
# <div class="browse-headline">
# <h1 class="headline-xl light brand-text text-title-dark">Find Colorectal Surgeons by city and state</h1>
# <a class="btn search-filter-btn" data-action="clickButton" data-event="vitalseventtracking" data-label="search_filter" href="/search?specialty=Colon and Rectal Surgery">
#                     search &amp; filter
#                 </a>
# </div>
# <div class="row">
# <div class="col s12 mobile-full">
# <ul class="tabs z-depth-1 tabs-fixed-width no-autoinit">
# <li class="tab"><a href="#A" target="_self">A</a></li>
# <li class="tab"><a href="#C" target="_self">C</a></li>
# <li class="tab"><a href="#D" target="_self">D</a></li>
# <li class="tab"><a href="#F" target="_self">F</a></li>
# <li class="tab"><a href="#G" target="_self">G</a></li>
# <li class="tab"><a href="#H" target="_self">H</a></li>
# <li class="tab"><a href="#I" target="_self">I</a></li>
# <li class="tab"><a href="#K" target="_self">K</a></li>
# <li class="tab"><a href="#L" target="_self">L</a></li>
# <li class="tab"><a href="#M" target="_self">M</a></li>
# <li class="tab"><a href="#N" target="_self">N</a></li>
# <li class="tab"><a href="#O" target="_self">O</a></li>
# <li class="tab"><a href="#P" target="_self">P</a></li>
# <li class="tab"><a href="#R" target="_self">R</a></li>
# <li class="tab"><a href="#S" target="_self">S</a></li>
# <li class="tab"><a href="#T" target="_self">T</a></li>
# <li class="tab"><a href="#U" target="_self">U</a></li>
# <li class="tab"><a href="#V" target="_self">V</a></li>
# <li class="tab"><a href="#W" target="_self">W</a></li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col xl4 l12 m12 s12">
# <div class="card short-desc">
# <div class="card-header">
# <h2 class="card-title">Colorectal Surgeons</h2>
# </div>
# <div class="card-content">
# <p class="truncated">Colorectal surgeons are doctors who perform surgery in order to correct problems with the anus, rectum or colon. These physicians perform colonoscopies, and other diagnostic procedures, <span> in order to identify any issues that require surgical intervention. They then determine what type of surgical procedure would be best. The specialists also care for these patients post-operation to ensure proper healing and recovery.</span></p>
# <a class="hide-on-large-and-up">SHOW </a>
# </div>
# </div>
# <div class="hide-on-large-and-down">
# <div class="traffic-driver traffic-driver-3 card">
# <div class="card-image">
# <img alt="Bowel Incontinence" src="//mdxvitals-res.cloudinary.com/image/upload/t_care/f_auto/v1488231048/all_care_guides/patientguide_bowel_incontinence.png"/>
# <h2 class="card-title">Bowel Incontinence</h2>
# </div>
# <div class="card-content">
# <p>Get the facts about bowel incontinence, including the causes and who is most at risk of developing it.</p>
# </div>
# <div class="card-action">
# <a data-traffic-driver="guidecard" href="/education/careguides/bowel-incontinence">view care guide</a>
# </div>
# </div> <ul class="traffic-driver traffic-driver-1 collection collection with-header z-depth-1">
# <li class="collection-header"><h2 class="collection-title">Care Guides</h2></li>
# <li class="collection-item avatar">
# <a data-action="click" data-event="vitalseventtracking" data-label="pictured_health_guide" data-traffic-driver="guide-list" href="/education/careguides/bowel-incontinence">
# <div class="circle tdss-10"></div>
# <span class="title deep-purple-text">Bowel Incontinence</span>
# <span class="truncate">Facts about bowel incontinence, including causes &amp; who's most at risk.</span>
# </a>
# <a class="secondary-content" data-traffic-driver="guidelist" href="/education/careguides/bowel-incontinence"><i class="icons-angle-right"></i></a>
# </li>
# <li class="collection-item avatar">
# <a data-action="click" data-event="vitalseventtracking" data-label="pictured_health_guide" data-traffic-driver="guide-list" href="/education/careguides/chronic-idiopathic-constipation">
# <div class="circle tdss-5"></div>
# <span class="title deep-purple-text">Chronic Idiopathic Constipation</span>
# <span class="truncate">Learn about chronic idiopathic constipation, including treatment</span>
# </a>
# <a class="secondary-content" data-traffic-driver="guidelist" href="/education/careguides/chronic-idiopathic-constipation"><i class="icons-angle-right"></i></a>
# </li>
# <li class="collection-item avatar">
# <a data-action="click" data-event="vitalseventtracking" data-label="pictured_health_guide" data-traffic-driver="guide-list" href="/education/careguides/colonoscopy">
# <div class="circle tdss-19"></div>
# <span class="title deep-purple-text">Colonoscopy</span>
# <span class="truncate">Facts about colonoscopy, including how and why it's done.</span>
# </a>
# <a class="secondary-content" data-traffic-driver="guidelist" href="/education/careguides/colonoscopy"><i class="icons-angle-right"></i></a>
# </li>
# <li class="collection-item avatar">
# <a data-action="click" data-event="vitalseventtracking" data-label="pictured_health_guide" data-traffic-driver="guide-list" href="/education/careguides/crohns-disease">
# <div class="circle tdss-11"></div>
# <span class="title deep-purple-text">Crohn's Disease</span>
# <span class="truncate">Facts about Crohn’s Disease, including how it affects the body.</span>
# </a>
# <a class="secondary-content" data-traffic-driver="guidelist" href="/education/careguides/crohns-disease"><i class="icons-angle-right"></i></a>
# </li>
# <li class="collection-item avatar">
# <a data-action="click" data-event="vitalseventtracking" data-label="pictured_health_guide" data-traffic-driver="guide-list" href="/education/careguides/ibs">
# <div class="circle tdss-8"></div>
# <span class="title deep-purple-text">IBS</span>
# <span class="truncate">Facts about Irritable Bowel Syndrome (IBS).</span>
# </a>
# <a class="secondary-content" data-traffic-driver="guidelist" href="/education/careguides/ibs"><i class="icons-angle-right"></i></a>
# </li>
# <li class="collection-item avatar">
# <a data-traffic-driver="guidelist" href="/education/careguides">
# <i class="icons-local-library circle grey-text text-darken-2 grey lighten-2"></i>
# <span class="title deep-purple-text">View All Care Guides</span>
# <span class="truncate">Prepare for your next visit with our extensive library of Care Guides</span>
# </a>
# <a class="secondary-content" data-action="click" data-event="vitalseventtracking" data-label="pictured_health_guide" data-traffic-driver="guidelist" href="/education/careguides"><i class="icons-angle-right"></i></a>
# </li>
# </ul> </div>
# <div class="rectangle-ad-bottom-slot">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="rectangle_pos3_bottom">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'rectangle_pos3_bottom'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col xl8 l12 m12 xl8-right-column s12">
# <ul class="columns c2">
# <li>
# <a name="A"></a>
# <div class="letter">A</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/al">
#         Alabama
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/al/birmingham">
#         Birmingham
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ak">
#         Alaska
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/az">
#         Arizona
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/az/phoenix">
#         Phoenix
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ar">
#         Arkansas
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ar/little-rock">
#         Little Rock
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="C"></a>
# <div class="letter">C</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ca">
#         California
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ca/los-angeles">
#         Los Angeles
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ca/sacramento">
#         Sacramento
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ca/san-diego">
#         San Diego
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ca/san-francisco">
#         San Francisco
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/co">
#         Colorado
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/co/aurora">
#         Aurora
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ct">
#         Connecticut
#     </a>
# </div>
# </li>
# <li>
# <a name="D"></a>
# <div class="letter">D</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/de">
#         Delaware
#     </a>
# </div>
# </li>
# <li>
# <a name="F"></a>
# <div class="letter">F</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/fl">
#         Florida
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/fl/jacksonville">
#         Jacksonville
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/fl/miami">
#         Miami
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/fl/orlando">
#         Orlando
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/fl/tampa">
#         Tampa
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/fl/weston">
#         Weston
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="G"></a>
# <div class="letter">G</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ga">
#         Georgia
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ga/atlanta">
#         Atlanta
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ga/augusta">
#         Augusta
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="H"></a>
# <div class="letter">H</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/hi">
#         Hawaii
#     </a>
# </div>
# </li>
# <li>
# <a name="I"></a>
# <div class="letter">I</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/id">
#         Idaho
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/il">
#         Illinois
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/il/chicago">
#         Chicago
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/in">
#         Indiana
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/in/fort-wayne">
#         Fort Wayne
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/in/indianapolis">
#         Indianapolis
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ia">
#         Iowa
#     </a>
# </div>
# </li>
# <li>
# <a name="K"></a>
# <div class="letter">K</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ks">
#         Kansas
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ky">
#         Kentucky
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ky/lexington">
#         Lexington
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="L"></a>
# <div class="letter">L</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/la">
#         Louisiana
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/la/new-orleans">
#         New Orleans
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="M"></a>
# <div class="letter">M</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/me">
#         Maine
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/md">
#         Maryland
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/md/baltimore">
#         Baltimore
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ma">
#         Massachusetts
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ma/boston">
#         Boston
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ma/burlington">
#         Burlington
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/mi">
#         Michigan
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/mn">
#         Minnesota
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/mn/minneapolis">
#         Minneapolis
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/mn/rochester">
#         Rochester
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/mn/saint-paul">
#         Saint Paul
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ms">
#         Mississippi
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/mo">
#         Missouri
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/mo/saint-louis">
#         Saint Louis
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/mt">
#         Montana
#     </a>
# </div>
# </li>
# <li>
# <a name="N"></a>
# <div class="letter">N</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ne">
#         Nebraska
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/nv">
#         Nevada
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/nh">
#         New Hampshire
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/nj">
#         New Jersey
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/nj/edison">
#         Edison
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/nm">
#         New Mexico
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ny">
#         New York
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ny/brooklyn">
#         Brooklyn
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ny/buffalo">
#         Buffalo
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ny/garden-city">
#         Garden City
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ny/great-neck">
#         Great Neck
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ny/new-york">
#         New York
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/ny/rochester">
#         Rochester
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/nc">
#         North Carolina
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/nd">
#         North Dakota
#     </a>
# </div>
# </li>
# <li>
# <a name="O"></a>
# <div class="letter">O</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/oh">
#         Ohio
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/oh/akron">
#         Akron
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/oh/cleveland">
#         Cleveland
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/oh/columbus">
#         Columbus
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ok">
#         Oklahoma
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/ok/tulsa">
#         Tulsa
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/or">
#         Oregon
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/or/portland">
#         Portland
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="P"></a>
# <div class="letter">P</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/pa">
#         Pennsylvania
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/pa/allentown">
#         Allentown
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/pa/philadelphia">
#         Philadelphia
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/pa/pittsburgh">
#         Pittsburgh
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <span class="grey-text text-darken-1">Puerto Rico</span>
# </li>
# <li>
# <a name="R"></a>
# <div class="letter">R</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ri">
#         Rhode Island
#     </a>
# </div>
# </li>
# <li>
# <a name="S"></a>
# <div class="letter">S</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/sc">
#         South Carolina
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/sd">
#         South Dakota
#     </a>
# </div>
# </li>
# <li>
# <a name="T"></a>
# <div class="letter">T</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/tn">
#         Tennessee
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/tx">
#         Texas
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/tx/austin">
#         Austin
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/tx/dallas">
#         Dallas
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/tx/houston">
#         Houston
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/tx/plano">
#         Plano
#     </a>
# </li>
# <li>
# <a href="/colorectal-surgeons/tx/san-antonio">
#         San Antonio
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="U"></a>
# <div class="letter">U</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/ut">
#         Utah
#     </a>
# </div>
# </li>
# <li>
# <a name="V"></a>
# <div class="letter">V</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/vt">
#         Vermont
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/va">
#         Virginia
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/va/fairfax">
#         Fairfax
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a name="W"></a>
# <div class="letter">W</div>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/wa">
#         Washington
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/wa/seattle">
#         Seattle
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/dc">
#         Washington DC
#     </a>
# <ul class="popular-cities">
# <li>
# <i class="icons-trending-up orange-text"></i>
# <span class="grey-text text-darken-1">Popular Cities</span>
# </li>
# <li>
# <a href="/colorectal-surgeons/dc/washington">
#         Washington
#     </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/wv">
#         West Virginia
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/wi">
#         Wisconsin
#     </a>
# </div>
# </li>
# <li>
# <div class="card-panel">
# <a href="/locations/colorectal-surgeons/wy">
#         Wyoming
#     </a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- right rail -->
# <div class="right-rail">
# <div class="rectangleDesktopAd">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="rectangle_all">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'rectangle_all'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="vitalsDisclaimer">
# <p class="xsmall">
#         The Vitals website is provided for your informational use only.
#         Nothing contained or offered by, on or through Vitals should be construed as medical
#         advice or relied upon for medical diagnosis or treatment. Vitals does not recommend or endorse any
#         particular healthcare provider whose information or ratings appear on this website.
#         We encourage you to read our full <a href="https://www.vitals.com/terms-of-use">Terms of Service</a>.
#     </p>
# </div>
# <div class="rectangleBottomDesktopAd">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="rectangle_pos2_bottom">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'rectangle_pos2_bottom'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div class="ad-leaderboard-bottom">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="leaderboard_bottom_browse">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'leaderboard_bottom_browse'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hide-on-med-and-up sticky-mobile-banner center">
# <div class="Advert-positionMark">
# <div class="Advert-wrapper Advert-wrapper--empty">
# <div class="">
# <div id="sticky_mob_banner">
# <script>
#                     window.adSlots = window.adSlots || [];
#                     window.adSlots.push({name: 'sticky_mob_banner'});
#                 </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="grey lighten-3">
# <div class="links container">
# <div class="grey lighten-3 footer-search-doctor-container">
# <h4 class="grey-text text-darken-2">Find Doctors by Name</h4>
# <ul>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/a">A</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/b">B</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/c">C</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/d">D</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/e">E</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/f">F</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/g">G</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/h">H</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/i">I</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/j">J</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/k">K</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/l">L</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/m">M</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/n">N</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/o">O</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/p">P</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/q">Q</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/r">R</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/s">S</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/t">T</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/u">U</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/v">V</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/w">W</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/x">X</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/y">Y</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="alpha" href="/directory/z">Z</a></li>
# </ul>
# </div>
# <div class="grey lighten-3 footer-links-container">
# <ul>
# <li><a class="cyan-text text-darken-2" data-footer="corporate" href="/feedback" rel="nofollow">SUPPORT</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="corporate" href="/faq" rel="nofollow">FAQ</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="corporate" href="/sitemap" rel="nofollow">SITEMAP</a></li>
# <li><a class="cyan-text text-darken-2" data-footer="corporate" href="/privacy" rel="nofollow">PRIVACY POLICY</a></li>
# </ul>
# </div>
# </div>
# <div class="copyright">
# <div class="container">
# <p class="grey-text text-darken-2">
#                 Copyright © 2020 Vitals Consumer Services, LLC. US Patent No. 8, 694, 441. All Rights Reserved.<br/>
#                 As more fully set forth in this website's <a class="cyan-text text-darken-2" href="/terms-of-use">terms of use</a>.
#                 (1) nothing contained on or offered by or through this website should be construed as medical advice and
#                 should not be relied upon for medical diagnosis or treatment. Vitals Consumer Services, LLC ("Vitals"). the provider of this
#                 website, does not recommend or endorse any particular healthcare provider whose information or ratings appear
#                 on this website; and (2) Vitals has granted you a limited license to access and use this website for your own
#                 noncommercial use. You are not permitted to copy, reproduce, distribute, transmit, mirror, frame, scrape,
#                 extract, wrap, create derivative works of, reverse engineer, decompile or disassemble any part or aspect of
#                 this website.
#             </p>
# </div>
# </div>
# </footer>
# <script src="/script/ads.js" type="text/javascript"></script><div id="oDZFVawsSnqk" style="display: none;"></div>
# <script type="text/javascript">
#
#         if(document.getElementById('oDZFVawsSnqk')){
#           oDZFVawsSnqk='No';
#         } else {
#           oDZFVawsSnqk='Yes';
#         }
#
#         if(typeof ga !=='undefined'){
#           ga('send','event','Blocking Ads',oDZFVawsSnqk,{'nonInteraction':1});
#         } else if(typeof _gaq !=='undefined'){
#           _gaq.push(['_trackEvent','Blocking Ads',oDZFVawsSnqk,undefined,undefined,true]);
#         }
#
#         </script>
# <aside class="sidenav no-autoinit right-aligned" id="slide-out">
# <h3 class="grey-text text-darken-2">Professionals and Specialists</h3>
# <ul data-sidenav="prof_spec">
# <li><a href="/dentists">Dentists</a></li>
# <li><a href="/podiatrists">Podiatrists</a></li>
# <li><a href="/chiropractors">Chiropractors</a></li>
# <li><a href="/optometrists">Optometrists</a></li>
# <li><a href="/locations/dermatologists">Dermatologists</a></li>
# <li><a href="/locations/endocrinologists">Endocrinologists</a></li>
# <li><a href="/locations/family-physicians">Family Physicians</a></li>
# <li><a href="/locations/neurologists">Neurologists</a></li>
# <li><a href="/locations/ophthalmologists">Ophthalmologists</a></li>
# <li><a href="/locations/obstetricians-gynecologists">Obstetricians &amp; Gynecologists</a></li>
# <li><a href="/locations/orthopedic-surgeons">Orthopedic Surgeons</a></li>
# <li><a href="/locations/pediatricians">Pediatricians</a></li>
# <li><a href="/locations/primary-care-doctors">Primary Care Doctors</a></li>
# <li><a href="/locations/gastroenterologists">Gastroenterologists</a></li>
# <li><a href="/locations/urologists">Urologists</a></li>
# <li><a href="/doctors">All Specialists</a></li>
# </ul>
# <h3 class="grey-text text-darken-2">Facilities</h3>
# <ul data-sidenav="facilities">
# <li><a href="/urgent-care">Urgent Care Centers</a></li>
# <li><a href="/pharmacy">Pharmacies</a></li>
# <li><a href="/nursing-home">Nursing Homes</a></li>
# <li><a href="/hospital">Hospitals</a></li>
# <li><a href="/group-practice">Group Practices</a></li>
# </ul>
# <h3 class="grey-text text-darken-2">Education</h3>
# <ul data-sidenav="education">
# <li><a href="/education/careguides/adult-asthma" rel="nofollow">Adult Asthma</a></li>
# <li><a href="/education/careguides/seasonal-allergies" rel="nofollow">Allergies</a></li>
# <li><a href="/education/careguides/atrial-fibrillation" rel="nofollow">Atrial Fibrillation</a></li>
# <li><a href="/education/careguides/bipolar-disorder" rel="nofollow">Bipolar Disorder</a></li>
# <li><a href="/education/careguides/copd" rel="nofollow">COPD</a></li>
# <li><a href="/education/careguides/childhood-asthma" rel="nofollow">Childhood Asthma</a></li>
# <li><a href="/education/careguides/hepatitis-c" rel="nofollow">Hepatitis C</a></li>
# <li><a href="/education/careguides/high-blood-pressure" rel="nofollow">High Blood Pressure</a></li>
# <li><a href="/education/careguides/high-cholesterol" rel="nofollow">High Cholesterol</a></li>
# <li><a href="/education/careguides/ibs" rel="nofollow">IBS</a></li>
# <li class="viewAll"><a href="/education/careguides" rel="nofollow">all care guides</a></li>
# </ul>
# <ul class="social" data-sidenav="corporate">
# <li><a href="https://www.facebook.com/Vitals" rel="nofollow"><i class="icons-facebook"></i></a></li>
# <li><a href="https://twitter.com/Vitals" rel="nofollow"><i class="icons-twitter"></i></a></li>
# <li><a href="https://www.linkedin.com/company/vitals-com" rel="nofollow"><i class="icons-linkedin"></i></a></li>
# <li><a href="https://pinterest.com/VitalsCom" rel="nofollow"><i class="icons-pinterest"></i></a></li>
# </ul>
# </aside>
# <script type="text/javascript">
#     var load = (function() {
#         // Function which returns a function
#         function _load(tag) {
#             return function(url, integrity, crossorigin) {
#                 integrity = integrity || false;
#                 crossorigin = crossorigin || false;
#                 // This promise will be used by Promise.all to determine success or failure
#                 return new Promise(function(resolve, reject) {
#                     var element = document.createElement(tag);
#                     var parent = 'body';
#                     var attr = 'src';
#                     // Important success and error for the promise
#                     element.onload = function() {
#                         resolve(url);
#                     };
#                     element.onerror = function() {
#                         reject(url);
#                     };
#                     // Need to set different attributes depending on tag type
#                     switch(tag) {
#                         case 'script':
#                             element.async = true;
#                             element.crossOrigin = 'anonymous';
#                             break;
#                         case 'link':
#                             element.type = 'text/css';
#                             element.rel = 'stylesheet';
#                             attr = 'href';
#                             parent = 'head';
#                     }
#                     if (integrity !== false) {
#                         element.integrity = integrity;
#                     }
#                     if (crossorigin !== false) {
#                         element.crossOrigin = crossorigin;
#                     }
#                     // Inject into document to kick off loading
#                     element[attr] = url;
#                     document[parent].appendChild(element);
#                 });
#             };
#         }
#         return {
#             css: _load('link'),
#             js:  _load('script'),
#             img: _load('img')
#         }
#     })();
#
#     // The big mamajama
#     function loadAll() {
#         Promise.all([
#             // Load CSS and jQuery first
#                         load.js('https://ajax.googleapis.com/ajax/libs/jquery/2.2.2/jquery.min.js'),
#         ]).then(function(){ return Promise.all([
#             // Load all other 3rd party scripts
#                             load.css('https://cdn.jsdelivr.net/npm/leaflet@1.3.4/dist/leaflet.min.css'),
#                 load.css('https://cdn.jsdelivr.net/npm/leaflet-routing-machine@3.2.11/dist/leaflet-routing-machine.min.css'),
#                 load.css('https://cdn.jsdelivr.net/npm/leaflet-control-geocoder@1.6.0/dist/Control.Geocoder.min.css'),
#                 load.js('https://cdn.jsdelivr.net/combine/npm/leaflet@1.3.4,npm/leaflet-routing-machine@3.2.11,npm/leaflet-control-geocoder@1.6.0'),
#                         load.js('https://cdn.jsdelivr.net/combine/npm/typeahead.js@0.11.1,npm/devbridge-autocomplete@1.4.7/dist/jquery.autocomplete.min.js'),
#             load.js('/script/materialize.min.dfd1a07905.js'),
#             load.js('https://cdn.jsdelivr.net/npm/lazysizes@4.1.4/lazysizes.min.js')
#         ])}).then(function(){ return Promise.all([
#             // Load first batch of our own JS
#                             load.js('/script/maps.min.5a0f5d934c.js'),
#                                         load.js('/script/features.min.cfcb76babe.js'),
#                 load.js('/script/slotConfig.min.b382e8db3c.js'),
#                 load.js('/script/globalMaterialize.min.39ce8e95c3.js')
#                     ])}).then(function(){
#             // This must be run after features is loaded and before search is loaded
#                           MDX.features = new MDX.Features({"dev.zocdocAdWidget":{"key":"dev.zocdocAdWidget","data":[],"active":true},"schema.summaryDescription":{"key":"schema.summaryDescription","data":[],"active":true},"schema.summaryRating":{"key":"schema.summaryRating","data":[],"active":true},"dev.sdPhpErrors":{"key":"dev.sdPhpErrors","data":[],"active":true},"sponsoredTabs.alzeto":{"key":"sponsoredTabs.alzeto","data":{"specs":["alim","derm","famp","genp","intm"],"targeting":"alzeto","copy":"Psoriasis Help"},"active":false},"searchHeader.useInstantSearch":{"key":"searchHeader.useInstantSearch","data":[],"active":true},"dev.useDrupalDrivers":{"key":"dev.useDrupalDrivers","data":[],"active":true},"trafficDriver.default":{"key":"trafficDriver.default","data":{"specs":["genp","intm"]},"active":false},"elasticSearch.browse":{"key":"elasticSearch.browse","data":{"indexName":"profile"},"active":true},"prs.usePrs2":{"key":"prs.usePrs2","data":[],"active":true},"showJsonld.enabled":{"key":"showJsonld.enabled","data":[],"active":false},"elasticSearch.profile":{"key":"elasticSearch.profile","data":{"indexName":"profile"},"active":true},"sponsoredTabs.artezno":{"key":"sponsoredTabs.artezno","data":{"specs":["acup","neur","pmed"],"targeting":"artezno","copy":"Migraine Help"},"active":false},"sponsoredTabs.qirtebrym":{"key":"sponsoredTabs.qirtebrym","data":{"specs":["geri","obgn","urol"],"targeting":"qirtebrym","copy":"OAB Help"},"active":false},"seo.notFound410":{"key":"seo.notFound410","data":[],"active":false},"live.trafficDrivers":{"key":"live.trafficDrivers","data":[],"active":true},"dev.newSummaryPage":{"key":"dev.newSummaryPage","data":[],"active":false},"prs.debugExposeToken":{"key":"prs.debugExposeToken","data":[],"active":false},"algoliaSearch.useCurl":{"key":"algoliaSearch.useCurl","data":[],"active":false},"sponsoredTabs.daelig":{"key":"sponsoredTabs.daelig","data":{"specs":["famp","genp","hema","hepa","infd","intm","path"],"targeting":"daelig","copy":"HIV Help"},"active":false},"algolia.browse":{"key":"algolia.browse","data":{"indexName":"vitals_browse"},"active":true},"dev.vitalsSolutionsLinks":{"key":"dev.vitalsSolutionsLinks","data":[],"active":true},"yext.enabled":{"key":"yext.enabled","data":[],"active":true},"groupPractice.routing":{"key":"groupPractice.routing","data":[],"active":true},"sponsoredTabs.aivunaj":{"key":"sponsoredTabs.aivunaj","data":{"specs":["adol","endo","famp","genp","hepa","intm","nutr","peds"],"targeting":"aivunaj","copy":"Diabetes Help"},"active":false},"dev.sdJsErrors":{"key":"dev.sdJsErrors","data":[],"active":true},"provider.match":{"key":"provider.match","data":[],"active":true},"algoliaSearch.useSwap":{"key":"algoliaSearch.useSwap","data":[],"active":false},"exp.materializeProfile":{"key":"exp.materializeProfile","data":[],"active":true},"seo.menuLocationLinkText":{"key":"seo.menuLocationLinkText","data":[],"active":false},"logging.404log":{"key":"logging.404log","data":[],"active":false},"addThisProfile.enabled":{"key":"addThisProfile.enabled","data":[],"active":false},"algolia.profile_highly_indexed":{"key":"algolia.profile_highly_indexed","data":{"indexName":"vitals_profile_highly_indexed"},"active":true},"algolia.profile":{"key":"algolia.profile","data":{"indexName":"vitals_profile"},"active":true},"dev.gpTabs":{"key":"dev.gpTabs","data":[],"active":false},"v2.enabled":{"key":"v2.enabled","data":[],"active":false},"schema.breadcrumbs":{"key":"schema.breadcrumbs","data":[],"active":false},"algolia.provider_reviews":{"key":"algolia.provider_reviews","data":{"indexName":"vitals_provider_reviews"},"active":true},"addThis.enabled":{"key":"addThis.enabled","data":[],"active":false},"dev.paidSerp":{"key":"dev.paidSerp","data":[],"active":true},"prs.maintenance":{"key":"prs.maintenance","data":[],"active":false},"debug.debugInfo":{"key":"debug.debugInfo","data":[],"active":false},"algolia.insurance":{"key":"algolia.insurance","data":{"indexName":"insurance_companies"},"active":true}});
#                     }).then(function() { return Promise.all([
#             // Search is a special child
#                             load.js('/script/search.min.6829c676f0.js')
#                     ])}).then(function(){
#                                         load.js('/script/bundle.min.a243687b6e.js')
#                     }).then(function(){
#                         // Finally, load everything else
#
#     $(document).ready(function () {
#         window.MDX = window.MDX || {};
#         window.MDX.adSlotConfigurations = window.MDX.adSlotConfigurations || {};
#                 window.MDX.advert = new window.MDX.Advert(window.MDX.adSlotConfigurations);
#         MDX.advert.setDfpNetwork('\/8905\/vitals\/');
#         MDX.advert.setZone('findadoctor');
#         MDX.advert.setPageTargeting({"zn":"findadoctor"});
#         MDX.advert.showAds();
#
#         //for GTM
#         window.MDX.adTags = {"zn":"findadoctor"};
#     });
#
#
#
#         var handledElementClicked = false;
#         $(document).ready(function() {
#             $(document).on("click", ".card a, .card", function() {
#
#                 if (handledElementClicked) {
#                     setTimeout(function() {
#                         handledElementClicked = false;
#                     }, 100);
#                     return;
#                 }
#
#                 handledElementClicked = true;
#
#                 var evLabel = 'unknown';
#
#                 if ($(this).is('div.card')) {
#                     evLabel = 'none_links';
#                 } else if ($(this).is('a')) {
#                     evLabel = $(this).data("label") || 'link';
#                 }
#
#                 var _dl= dataLayer || [];
#                 _dl.push({'event':'vitalseventtracking','eventAction':'click','eventCategory':'searchCard','eventLabel':evLabel});
#
#             });
#         });
#
#
#
#         $(document).ready(function() {
#             $('.short-desc').on('click', 'a', function(e){
#                 e.preventDefault();
#                 $(this).prev('.truncated').toggleClass('show');
#             });
#         });
#
#                                 if (window.postDeferJS) {
#                 for (i = 0; i < postDeferJS.length; i++) {
#                     postDeferJS[i]();
#                 }
#             }
#             // Materalize auto-init JS components.
#             M.AutoInit();
#             // custom materialize js settings, should be loaded after Materalize auto-init in order not to be overwritten by the Materalize defaults
#                                                                                             }).catch(function(err) {
#                     });
#     }
#
#     // Checking for native promise support (IE11 basically...)
#     if (window.Promise) {
#       loadAll();
#     } else {
#         // Special loading of Promise polyfill
#         var js = document.createElement('script');
#         js.src = '//cdn.jsdelivr.net/bluebird/3.5.0/bluebird.min.js';
#         js.onload = function() {
#           loadAll();
#         };
#         js.onerror = function() {
#           done(new Error('Failed to load bluebird'));
#         };
#         document.head.appendChild(js);
#     }
# </script><script async="" crossorigin="anonymous" src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.2/jquery.min.js"></script>
# <script src="https://img.webmd.com/bi_common/bi_consumer.js?d=08/27/2020" type="text/javascript"></script>
# <script async="" crossorigin="anonymous" src="https://cdn.jsdelivr.net/combine/npm/leaflet@1.3.4,npm/leaflet-routing-machine@3.2.11,npm/leaflet-control-geocoder@1.6.0"></script><script async="" crossorigin="anonymous" src="https://cdn.jsdelivr.net/combine/npm/typeahead.js@0.11.1,npm/devbridge-autocomplete@1.4.7/dist/jquery.autocomplete.min.js"></script><script async="" crossorigin="anonymous" src="/script/materialize.min.dfd1a07905.js"></script><script async="" crossorigin="anonymous" src="https://cdn.jsdelivr.net/npm/lazysizes@4.1.4/lazysizes.min.js"></script><script>
# try {
#     var ccpaBannerLinks = {
#         cookieLink: '',
#         privacyPolicyLink: ''
#     };
#     var ccpaTestParam = ''
#
#     if (window.location.hostname.indexOf('webmd.com') > -1) {
#         ccpaBannerLinks.cookieLink = 'https%3A%2F%2Fwww.webmd.com%2Fabout-webmd-policies%2Fabout-california-privacy-policy';
#         ccpaBannerLinks.privacyPolicyLink = 'https%3A%2F%2Fwww.webmd.com%2Fabout-webmd-policies%2Fabout-privacy-policy';
#     } else if (window.location.hostname.indexOf('vitals.com') > -1) {
#         ccpaBannerLinks.cookieLink = 'https%3A%2F%2Fwww.vitals.com%2Fcalifornia-privacy-disclosure';
#         ccpaBannerLinks.privacyPolicyLink = 'https%3A%2F%2Fwww.vitals.com%2Fprivacy';
#     } else if (window.location.hostname.indexOf('medicinenet.com') > -1) {
#         ccpaBannerLinks.cookieLink = 'https%3A%2F%2Fwww.medicinenet.com%2Fcalifornia_resident_privacy_notice%2Farticle.htm';
#         ccpaBannerLinks.privacyPolicyLink = 'https%3A%2F%2Fwww.medicinenet.com%2Fscript%2Fmain%2Fart.asp%3Farticlekey%3D12507';
#     } else if (window.location.hostname.indexOf('emedicinehealth.com') > -1) {
#         ccpaBannerLinks.cookieLink = 'https%3A%2F%2Fwww.emedicinehealth.com%2Fscript%2Fmain%2Fart.asp%3Farticlekey%3D226573';
#         ccpaBannerLinks.privacyPolicyLink = 'https%3A%2F%2Fwww.emedicinehealth.com%2Fscript%2Fmain%2Fart.asp%3Farticlekey%3D60180';
#     } else if (window.location.hostname.indexOf('rxlist.com') > -1) {
#         ccpaBannerLinks.cookieLink = 'https%3A%2F%2Fwww.rxlist.com%2Fscript%2Fmain%2Fart.asp%3Farticlekey%3D226574';
#         ccpaBannerLinks.privacyPolicyLink = 'https%3A%2F%2Fwww.rxlist.com%2Fscript%2Fmain%2Fart.asp%3Farticlekey%3D64474';
#     } else if (window.location.hostname.indexOf('onhealth.com') > -1) {
#         ccpaBannerLinks.cookieLink = 'https%3A%2F%2Fwww.onhealth.com%2Fcontent%2F3%2Fcalifornia_resident_privacy_notice';
#         ccpaBannerLinks.privacyPolicyLink = 'https%3A%2F%2Fwww.onhealth.com%2Fcontent%2F3%2Fprivacy_policy';
#     }
#
#     // Create Trust Arc Banner CSS
#     var trustArcBannerCSS = document.createElement('style');
#     trustArcBannerCSS.type = 'text/css';
#     var trustArcBannerStyles = '#consent_blackbar {position: fixed; bottom: 0; width: 100%; z-index: 100000000000000;}';
#     trustArcBannerStyles += '.truste-button2 {box-shadow: none;}';
#     trustArcBannerStyles += '.truste-button2:hover {background-color: inherit;}';
#     trustArcBannerStyles += '@media screen and (max-width: 790px){.truste-button2 {position: absolute !important;}}';
#     if (trustArcBannerCSS.styleSheet) trustArcBannerCSS.styleSheet.cssText = trustArcBannerStyles;
#     else trustArcBannerCSS.appendChild(document.createTextNode(trustArcBannerStyles));
#     document.getElementsByTagName('head')[0].appendChild(trustArcBannerCSS);
#
#     // Create Trust Arc Banner Div
#     var trustArcBanner = document.createElement('div');
#     trustArcBanner.id = 'consent_blackbar';
#     document.getElementsByTagName('body')[0].appendChild(trustArcBanner);
#
#     if (window.location.search.indexOf('ccpa') > -1) {
#         ccpaTestParam = '&state=ca';
#     }
#
#     // Create Trust Arc Script
#     var trustArcScript = document.createElement('script');
#     trustArcScript.async = 'async';
#     trustArcScript.src = '//consent.trustarc.com/notice?domain=webmd.com'+ccpaTestParam+'&c=teconsent&js=nj&noticeType=bb&text=true&cookieLink='+ccpaBannerLinks.cookieLink+'&privacypolicylink='+ccpaBannerLinks.privacyPolicyLink;
#     document.getElementsByTagName('body')[0].appendChild(trustArcScript);
# }
# catch(error) {}
# </script><div id="consent_blackbar"></div><script async="" src="//consent.trustarc.com/notice?domain=webmd.com&amp;c=teconsent&amp;js=nj&amp;noticeType=bb&amp;text=true&amp;cookieLink=https%3A%2F%2Fwww.vitals.com%2Fcalifornia-privacy-disclosure&amp;privacypolicylink=https%3A%2F%2Fwww.vitals.com%2Fprivacy"></script><script id="" type="text/javascript">s_context["wb.busref"]=google_tag_manager["GTM-W55B"].macro(3);</script><script>_satellite["__runScript1"](function(event, target) {
# !function(e,t){var n=document.createElement("script");n.onload=n.onreadystatechange=function(e){("load"===(e||window.event).type||/loaded|complete/.test(n.readyState)&&document.documentMode<=11)&&(n.onload=n.onreadystatechange=n.onerror=null,new IBTracker(t))},n.onerror=function(){n.onload=n.onreadystatechange=n.onerror=null},n.async=1,n.src=e,n.setAttribute("crossorigin","anonymous"),document.getElementsByTagName("head")[0].appendChild(n)}("https://ibclick.stream/assets/js/track/dist/js/v1/tracker.min.js",{site:"webmddev"!==window.s_account?"webmd.com":"staging.webmd.com",vertical:"health consumer",autoPageViewTracking:!0,autoClickTracking:!0,snippetVersion:"1.2"});
# });</script><script>_satellite["__runScript2"](function(event, target) {
# try{var uiCookie=webmd.cookie.getJson("ui"),expCalls=uiCookie.expmatch||0,turnID=webmd.cookie.get("turn"),pvid=window.s_pageview_id||"";0===expCalls||expCalls<3&&!turnID?(webmd.debug!==undefined&&webmd.debug("matchback beacon call - try #"+(expCalls+1)+"..."),$("<iframe/>").attr({id:"matchbackBeacon",src:"//img.webmd.com/pixel/aiq.a.html?domain="+webmd.url.getSLD()+"&pvid="+pvid,style:"width:0px; height:0px; border:0px;"}).appendTo("body"),uiCookie.expmatch=expCalls+1,webmd.cookie.setJson("ui",uiCookie,{domain:webmd.url.getSLD()}),webmd.debug!==undefined&&webmd.debug("matchback beacon call done.")):webmd.debug!==undefined&&webmd.debug("matchback beacon not needed.")}catch(error){}
# });</script><iframe class="aamIframeLoaded" id="destination_publishing_iframe_webmd_0" name="destination_publishing_iframe_webmd_0_name" sandbox="allow-scripts allow-same-origin" src="https://webmd.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fwww.vitals.com" style="display: none; width: 0px; height: 0px;" title="Adobe ID Syncing iFrame"></iframe><script async="" crossorigin="anonymous" src="/script/maps.min.5a0f5d934c.js"></script><script async="" crossorigin="anonymous" src="/script/features.min.cfcb76babe.js"></script><script async="" crossorigin="anonymous" src="/script/slotConfig.min.b382e8db3c.js"></script><script async="" crossorigin="anonymous" src="/script/globalMaterialize.min.39ce8e95c3.js"></script><div class="sidenav-overlay"></div><div class="drag-target right-aligned"></div><script async="" crossorigin="anonymous" src="/script/search.min.6829c676f0.js"></script><iframe height="0" name="ibtransporter" src="https://ibclick.stream/ib.html" style="display: none; visibility: hidden;" width="0"></iframe></body></html>

# %% [markdown]
# ## Finding states

# %%
states = []
state_links = []

# %%
state = soup.find_all('div', attrs = {'class':'card-panel'})
state
# Out:
# [<div class="card-panel">
#  <a href="/locations/colorectal-surgeons/al">
#          Alabama
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/al/birmingham">
#          Birmingham
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ak">
#          Alaska
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/az">
#          Arizona
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/az/phoenix">
#          Phoenix
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ar">
#          Arkansas
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ar/little-rock">
#          Little Rock
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ca">
#          California
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ca/los-angeles">
#          Los Angeles
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ca/sacramento">
#          Sacramento
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ca/san-diego">
#          San Diego
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ca/san-francisco">
#          San Francisco
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/co">
#          Colorado
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/co/aurora">
#          Aurora
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ct">
#          Connecticut
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/de">
#          Delaware
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/fl">
#          Florida
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/fl/jacksonville">
#          Jacksonville
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/fl/miami">
#          Miami
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/fl/orlando">
#          Orlando
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/fl/tampa">
#          Tampa
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/fl/weston">
#          Weston
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ga">
#          Georgia
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ga/atlanta">
#          Atlanta
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ga/augusta">
#          Augusta
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/hi">
#          Hawaii
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/id">
#          Idaho
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/il">
#          Illinois
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/il/chicago">
#          Chicago
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/in">
#          Indiana
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/in/fort-wayne">
#          Fort Wayne
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/in/indianapolis">
#          Indianapolis
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ia">
#          Iowa
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ks">
#          Kansas
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ky">
#          Kentucky
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ky/lexington">
#          Lexington
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/la">
#          Louisiana
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/la/new-orleans">
#          New Orleans
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/me">
#          Maine
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/md">
#          Maryland
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/md/baltimore">
#          Baltimore
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ma">
#          Massachusetts
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ma/boston">
#          Boston
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ma/burlington">
#          Burlington
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/mi">
#          Michigan
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/mn">
#          Minnesota
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/mn/minneapolis">
#          Minneapolis
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/mn/rochester">
#          Rochester
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/mn/saint-paul">
#          Saint Paul
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ms">
#          Mississippi
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/mo">
#          Missouri
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/mo/saint-louis">
#          Saint Louis
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/mt">
#          Montana
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ne">
#          Nebraska
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/nv">
#          Nevada
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/nh">
#          New Hampshire
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/nj">
#          New Jersey
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/nj/edison">
#          Edison
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/nm">
#          New Mexico
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ny">
#          New York
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ny/brooklyn">
#          Brooklyn
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ny/buffalo">
#          Buffalo
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ny/garden-city">
#          Garden City
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ny/great-neck">
#          Great Neck
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ny/new-york">
#          New York
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ny/rochester">
#          Rochester
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/nc">
#          North Carolina
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/nd">
#          North Dakota
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/oh">
#          Ohio
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/oh/akron">
#          Akron
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/oh/cleveland">
#          Cleveland
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/oh/columbus">
#          Columbus
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ok">
#          Oklahoma
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/ok/tulsa">
#          Tulsa
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/or">
#          Oregon
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/or/portland">
#          Portland
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/pa">
#          Pennsylvania
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/pa/allentown">
#          Allentown
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/pa/philadelphia">
#          Philadelphia
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/pa/pittsburgh">
#          Pittsburgh
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ri">
#          Rhode Island
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/sc">
#          South Carolina
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/sd">
#          South Dakota
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/tn">
#          Tennessee
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/tx">
#          Texas
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/tx/austin">
#          Austin
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/tx/dallas">
#          Dallas
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/tx/houston">
#          Houston
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/tx/plano">
#          Plano
#      </a>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/tx/san-antonio">
#          San Antonio
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/ut">
#          Utah
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/vt">
#          Vermont
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/va">
#          Virginia
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/va/fairfax">
#          Fairfax
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/wa">
#          Washington
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/wa/seattle">
#          Seattle
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/dc">
#          Washington DC
#      </a>
#  <ul class="popular-cities">
#  <li>
#  <i class="icons-trending-up orange-text"></i>
#  <span class="grey-text text-darken-1">Popular Cities</span>
#  </li>
#  <li>
#  <a href="/colorectal-surgeons/dc/washington">
#          Washington
#      </a>
#  </li>
#  </ul>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/wv">
#          West Virginia
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/wi">
#          Wisconsin
#      </a>
#  </div>, <div class="card-panel">
#  <a href="/locations/colorectal-surgeons/wy">
#          Wyoming
#      </a>
#  </div>]

# %%
p = str(state)
index_of_href = [i for i in range(len(p)) if p.startswith('''href''', i)]

# %%
index_of_end = []
for i in index_of_href:
#     print(i)
    index = p[i:].find('''">''')
#     print("index", index)
    index_of_end.append(index + i)

# %%
index_of_end_a = []
for i in index_of_href:
    index = p[i:].find("</a>")
    index_of_end_a.append(index + i)

# %%
for i in range(len(index_of_end_a)):
    temp1 = p[index_of_href[i]+6: index_of_end[i]].strip()
    temp2 = p[index_of_end[i]+2 : index_of_end_a[i]].strip()
    states.append(temp2)
    state_links.append(temp1)

# %%
print(states, state_links, sep = "\n\n\n")
# Out:
# ['Alabama', 'Birmingham', 'Alaska', 'Arizona', 'Phoenix', 'Arkansas', 'Little Rock', 'California', 'Los Angeles', 'Sacramento', 'San Diego', 'San Francisco', 'Colorado', 'Aurora', 'Connecticut', 'Delaware', 'Florida', 'Jacksonville', 'Miami', 'Orlando', 'Tampa', 'Weston', 'Georgia', 'Atlanta', 'Augusta', 'Hawaii', 'Idaho', 'Illinois', 'Chicago', 'Indiana', 'Fort Wayne', 'Indianapolis', 'Iowa', 'Kansas', 'Kentucky', 'Lexington', 'Louisiana', 'New Orleans', 'Maine', 'Maryland', 'Baltimore', 'Massachusetts', 'Boston', 'Burlington', 'Michigan', 'Minnesota', 'Minneapolis', 'Rochester', 'Saint Paul', 'Mississippi', 'Missouri', 'Saint Louis', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'Edison', 'New Mexico', 'New York', 'Brooklyn', 'Buffalo', 'Garden City', 'Great Neck', 'New York', 'Rochester', 'North Carolina', 'North Dakota', 'Ohio', 'Akron', 'Cleveland', 'Columbus', 'Oklahoma', 'Tulsa', 'Oregon', 'Portland', 'Pennsylvania', 'Allentown', 'Philadelphia', 'Pittsburgh', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Austin', 'Dallas', 'Houston', 'Plano', 'San Antonio', 'Utah', 'Vermont', 'Virginia', 'Fairfax', 'Washington', 'Seattle', 'Washington DC', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
#
#
# ['/locations/colorectal-surgeons/al', '/colorectal-surgeons/al/birmingham', '/locations/colorectal-surgeons/ak', '/locations/colorectal-surgeons/az', '/colorectal-surgeons/az/phoenix', '/locations/colorectal-surgeons/ar', '/colorectal-surgeons/ar/little-rock', '/locations/colorectal-surgeons/ca', '/colorectal-surgeons/ca/los-angeles', '/colorectal-surgeons/ca/sacramento', '/colorectal-surgeons/ca/san-diego', '/colorectal-surgeons/ca/san-francisco', '/locations/colorectal-surgeons/co', '/colorectal-surgeons/co/aurora', '/locations/colorectal-surgeons/ct', '/locations/colorectal-surgeons/de', '/locations/colorectal-surgeons/fl', '/colorectal-surgeons/fl/jacksonville', '/colorectal-surgeons/fl/miami', '/colorectal-surgeons/fl/orlando', '/colorectal-surgeons/fl/tampa', '/colorectal-surgeons/fl/weston', '/locations/colorectal-surgeons/ga', '/colorectal-surgeons/ga/atlanta', '/colorectal-surgeons/ga/augusta', '/locations/colorectal-surgeons/hi', '/locations/colorectal-surgeons/id', '/locations/colorectal-surgeons/il', '/colorectal-surgeons/il/chicago', '/locations/colorectal-surgeons/in', '/colorectal-surgeons/in/fort-wayne', '/colorectal-surgeons/in/indianapolis', '/locations/colorectal-surgeons/ia', '/locations/colorectal-surgeons/ks', '/locations/colorectal-surgeons/ky', '/colorectal-surgeons/ky/lexington', '/locations/colorectal-surgeons/la', '/colorectal-surgeons/la/new-orleans', '/locations/colorectal-surgeons/me', '/locations/colorectal-surgeons/md', '/colorectal-surgeons/md/baltimore', '/locations/colorectal-surgeons/ma', '/colorectal-surgeons/ma/boston', '/colorectal-surgeons/ma/burlington', '/locations/colorectal-surgeons/mi', '/locations/colorectal-surgeons/mn', '/colorectal-surgeons/mn/minneapolis', '/colorectal-surgeons/mn/rochester', '/colorectal-surgeons/mn/saint-paul', '/locations/colorectal-surgeons/ms', '/locations/colorectal-surgeons/mo', '/colorectal-surgeons/mo/saint-louis', '/locations/colorectal-surgeons/mt', '/locations/colorectal-surgeons/ne', '/locations/colorectal-surgeons/nv', '/locations/colorectal-surgeons/nh', '/locations/colorectal-surgeons/nj', '/colorectal-surgeons/nj/edison', '/locations/colorectal-surgeons/nm', '/locations/colorectal-surgeons/ny', '/colorectal-surgeons/ny/brooklyn', '/colorectal-surgeons/ny/buffalo', '/colorectal-surgeons/ny/garden-city', '/colorectal-surgeons/ny/great-neck', '/colorectal-surgeons/ny/new-york', '/colorectal-surgeons/ny/rochester', '/locations/colorectal-surgeons/nc', '/locations/colorectal-surgeons/nd', '/locations/colorectal-surgeons/oh', '/colorectal-surgeons/oh/akron', '/colorectal-surgeons/oh/cleveland', '/colorectal-surgeons/oh/columbus', '/locations/colorectal-surgeons/ok', '/colorectal-surgeons/ok/tulsa', '/locations/colorectal-surgeons/or', '/colorectal-surgeons/or/portland', '/locations/colorectal-surgeons/pa', '/colorectal-surgeons/pa/allentown', '/colorectal-surgeons/pa/philadelphia', '/colorectal-surgeons/pa/pittsburgh', '/locations/colorectal-surgeons/ri', '/locations/colorectal-surgeons/sc', '/locations/colorectal-surgeons/sd', '/locations/colorectal-surgeons/tn', '/locations/colorectal-surgeons/tx', '/colorectal-surgeons/tx/austin', '/colorectal-surgeons/tx/dallas', '/colorectal-surgeons/tx/houston', '/colorectal-surgeons/tx/plano', '/colorectal-surgeons/tx/san-antonio', '/locations/colorectal-surgeons/ut', '/locations/colorectal-surgeons/vt', '/locations/colorectal-surgeons/va', '/colorectal-surgeons/va/fairfax', '/locations/colorectal-surgeons/wa', '/colorectal-surgeons/wa/seattle', '/locations/colorectal-surgeons/dc', '/colorectal-surgeons/dc/washington', '/locations/colorectal-surgeons/wv', '/locations/colorectal-surgeons/wi', '/locations/colorectal-surgeons/wy']

# %% [markdown]
# ## Removing popular cities

# %%
index_of_popular_cities = []
for index, i in enumerate(state_links):
#     print(i)
#     print(i.find('''locations'''))
    if i.find('''locations''') == -1:
        index_of_popular_cities.append(index)

# %%
print(index_of_popular_cities)
# Out:
# [1, 4, 6, 8, 9, 10, 11, 13, 17, 18, 19, 20, 21, 23, 24, 28, 30, 31, 35, 37, 40, 42, 43, 46, 47, 48, 51, 57, 60, 61, 62, 63, 64, 65, 69, 70, 71, 73, 75, 77, 78, 79, 85, 86, 87, 88, 89, 93, 95, 97]

# %%
temp_state = states[:]
temp_state_links = state_links[:]
states = []
state_links = []
for index, ele in enumerate(temp_state_links):
    if index in index_of_popular_cities:
        continue
    else:
        state_links.append(ele)
for index, ele in enumerate(temp_state):
    if index in index_of_popular_cities:
        continue
    else:
        states.append(ele)

# %%
print(states, state_links, sep = "\n\n\n")
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'Washington DC', 'West Virginia', 'Wisconsin', 'Wyoming']
#
#
# ['/locations/colorectal-surgeons/al', '/locations/colorectal-surgeons/ak', '/locations/colorectal-surgeons/az', '/locations/colorectal-surgeons/ar', '/locations/colorectal-surgeons/ca', '/locations/colorectal-surgeons/co', '/locations/colorectal-surgeons/ct', '/locations/colorectal-surgeons/de', '/locations/colorectal-surgeons/fl', '/locations/colorectal-surgeons/ga', '/locations/colorectal-surgeons/hi', '/locations/colorectal-surgeons/id', '/locations/colorectal-surgeons/il', '/locations/colorectal-surgeons/in', '/locations/colorectal-surgeons/ia', '/locations/colorectal-surgeons/ks', '/locations/colorectal-surgeons/ky', '/locations/colorectal-surgeons/la', '/locations/colorectal-surgeons/me', '/locations/colorectal-surgeons/md', '/locations/colorectal-surgeons/ma', '/locations/colorectal-surgeons/mi', '/locations/colorectal-surgeons/mn', '/locations/colorectal-surgeons/ms', '/locations/colorectal-surgeons/mo', '/locations/colorectal-surgeons/mt', '/locations/colorectal-surgeons/ne', '/locations/colorectal-surgeons/nv', '/locations/colorectal-surgeons/nh', '/locations/colorectal-surgeons/nj', '/locations/colorectal-surgeons/nm', '/locations/colorectal-surgeons/ny', '/locations/colorectal-surgeons/nc', '/locations/colorectal-surgeons/nd', '/locations/colorectal-surgeons/oh', '/locations/colorectal-surgeons/ok', '/locations/colorectal-surgeons/or', '/locations/colorectal-surgeons/pa', '/locations/colorectal-surgeons/ri', '/locations/colorectal-surgeons/sc', '/locations/colorectal-surgeons/sd', '/locations/colorectal-surgeons/tn', '/locations/colorectal-surgeons/tx', '/locations/colorectal-surgeons/ut', '/locations/colorectal-surgeons/vt', '/locations/colorectal-surgeons/va', '/locations/colorectal-surgeons/wa', '/locations/colorectal-surgeons/dc', '/locations/colorectal-surgeons/wv', '/locations/colorectal-surgeons/wi', '/locations/colorectal-surgeons/wy']
